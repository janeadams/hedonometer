# %%
import pickle
import pandas as pd
from datetime import datetime
import random

import plotly.offline as py
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
mypath = "daily_onegrams/daily_ranks_pickle"

# %%
from os import listdir
from os.path import isfile, join
wordlist = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
wordlist
# Out:
# ['#ช.pkl',
#  'marvin.pkl',
#  '된.pkl',
#  'viewing.pkl',
#  'adoro.pkl',
#  'hoga.pkl',
#  'birra.pkl',
#  'primeiros.pkl',
#  'as.pkl',
#  'temas.pkl',
#  'تطلع.pkl',
#  '얼른.pkl',
#  'нахуй.pkl',
#  'compartiendo.pkl',
#  'clara.pkl',
#  '75.pkl',
#  'się.pkl',
#  '캐.pkl',
#  '대충.pkl',
#  'あざす.pkl',
#  'vieron.pkl',
#  'stu.pkl',
#  'dieta.pkl',
#  'leadership.pkl',
#  'mp.pkl',
#  'joyful.pkl',
#  'نزل.pkl',
#  'making.pkl',
#  'شريك.pkl',
#  'kuota.pkl',
#  'mouth.pkl',
#  '148.pkl',
#  'karol.pkl',
#  'がんばろ.pkl',
#  'dan.pkl',
#  'موسى.pkl',
#  'amada.pkl',
#  'تعب.pkl',
#  'neutral.pkl',
#  'curta.pkl',
#  'culo.pkl',
#  'verge.pkl',
#  'terrain.pkl',
#  'เวลา.pkl',
#  'altında.pkl',
#  'このツイートをrt.pkl',
#  'nuevo.pkl',
#  'lane.pkl',
#  'roughly.pkl',
#  'نام.pkl',
#  'الوطن.pkl',
#  'aşık.pkl',
#  'volví.pkl',
#  'حظي.pkl',
#  'siege.pkl',
#  'darling.pkl',
#  'كلامه.pkl',
#  'sagittarius.pkl',
#  'منا.pkl',
#  'teenage.pkl',
#  '404.pkl',
#  'dmm.pkl',
#  'dnv.pkl',
#  'wi.pkl',
#  'jeep.pkl',
#  'safada.pkl',
#  'รอยย.pkl',
#  'ark.pkl',
#  'book.pkl',
#  'tote.pkl',
#  'ترك.pkl',
#  'natal.pkl',
#  'musun.pkl',
#  'noticing.pkl',
#  'بدا.pkl',
#  'ไ.pkl',
#  '없음.pkl',
#  'virgen.pkl',
#  'anthony.pkl',
#  'pantalones.pkl',
#  'غير.pkl',
#  'прямо.pkl',
#  '1999.pkl',
#  'حيث.pkl',
#  'för.pkl',
#  'surface.pkl',
#  'ใคร.pkl',
#  'งข.pkl',
#  'promoción.pkl',
#  'edu.pkl',
#  'comenzar.pkl',
#  'タグ反応ありがとうございます.pkl',
#  'fudido.pkl',
#  'saludo.pkl',
#  'delicious.pkl',
#  'minds.pkl',
#  'فسيح.pkl',
#  'paragraph.pkl',
#  'ちゃんと.pkl',
#  'affected.pkl',
#  'bardzo.pkl',
#  'ᵒ.pkl',
#  'protector.pkl',
#  '1972.pkl',
#  'desespero.pkl',
#  'unlimited.pkl',
#  'controller.pkl',
#  '#dance.pkl',
#  'gatos.pkl',
#  'ㄹㅇ.pkl',
#  'daha.pkl',
#  '#google.pkl',
#  'flash.pkl',
#  'calles.pkl',
#  'sıra.pkl',
#  'pregunta.pkl',
#  'dolayı.pkl',
#  'พท.pkl',
#  'onların.pkl',
#  'starving.pkl',
#  'failing.pkl',
#  'oakland.pkl',
#  'isis.pkl',
#  'designed.pkl',
#  'ended.pkl',
#  'moda.pkl',
#  'casino.pkl',
#  'merdas.pkl',
#  'کم.pkl',
#  'اللى.pkl',
#  'pasal.pkl',
#  '#fashion.pkl',
#  '#femdom.pkl',
#  'deleting.pkl',
#  '하나만.pkl',
#  'méxico.pkl',
#  'д.pkl',
#  'skies.pkl',
#  'wla.pkl',
#  'difference.pkl',
#  'away.pkl',
#  'lambat.pkl',
#  'alto.pkl',
#  'کل.pkl',
#  'やりたい.pkl',
#  'pho.pkl',
#  'influence.pkl',
#  'понимаю.pkl',
#  'i̇slam.pkl',
#  'อไม.pkl',
#  'personajes.pkl',
#  'items.pkl',
#  'ぼく.pkl',
#  'eran.pkl',
#  'quoting.pkl',
#  'semanas.pkl',
#  'iii.pkl',
#  'ligar.pkl',
#  'birmingham.pkl',
#  'hanno.pkl',
#  'puppies.pkl',
#  '面白い.pkl',
#  'caja.pkl',
#  'اليك.pkl',
#  'resolved.pkl',
#  'controlled.pkl',
#  '보면서.pkl',
#  'tick.pkl',
#  'triple.pkl',
#  'depan.pkl',
#  '9am.pkl',
#  'esperamos.pkl',
#  'crawl.pkl',
#  'aiming.pkl',
#  'positif.pkl',
#  'supe.pkl',
#  'peki.pkl',
#  'invade.pkl',
#  'tysm.pkl',
#  'preview.pkl',
#  'campaigns.pkl',
#  'gestión.pkl',
#  'minuten.pkl',
#  'orchestra.pkl',
#  'stupid.pkl',
#  'pra.pkl',
#  'battery.pkl',
#  'bisous.pkl',
#  'ชอบก.pkl',
#  'efficient.pkl',
#  'victoria.pkl',
#  'macho.pkl',
#  'ولكل.pkl',
#  'حكم.pkl',
#  '그러나.pkl',
#  'gül.pkl',
#  'grita.pkl',
#  'h&amp.pkl',
#  'series.pkl',
#  'alan.pkl',
#  'kik.pkl',
#  'البداية.pkl',
#  'önce.pkl',
#  'jamaica.pkl',
#  'dikasih.pkl',
#  'bai.pkl',
#  '그걸.pkl',
#  'απο.pkl',
#  'ребята.pkl',
#  'aunt.pkl',
#  'فيما.pkl',
#  'wonwoo.pkl',
#  'está.pkl',
#  'sooooo.pkl',
#  'pickup.pkl',
#  '몇.pkl',
#  'thru.pkl',
#  'importantly.pkl',
#  'こちらこそよろしくお願いします.pkl',
#  'men.pkl',
#  'cube.pkl',
#  'ยงใหม.pkl',
#  'بدر.pkl',
#  'tio.pkl',
#  'ömür.pkl',
#  'pirate.pkl',
#  'ณ.pkl',
#  '다양한.pkl',
#  'sotto.pkl',
#  'ฮร.pkl',
#  'یہ.pkl',
#  'как.pkl',
#  'certains.pkl',
#  'งเก.pkl',
#  'formal.pkl',
#  'satu.pkl',
#  'crimes.pkl',
#  'mim.pkl',
#  'tfw.pkl',
#  'observation.pkl',
#  'bana.pkl',
#  'diabetes.pkl',
#  'etti.pkl',
#  'x1.pkl',
#  'drained.pkl',
#  'kristen.pkl',
#  'container.pkl',
#  'iran.pkl',
#  'summer.pkl',
#  '149.pkl',
#  'morro.pkl',
#  'تسأل.pkl',
#  'support.pkl',
#  'านค.pkl',
#  'sack.pkl',
#  'কর.pkl',
#  'rainha.pkl',
#  'penis.pkl',
#  'lockscreen.pkl',
#  'alguma.pkl',
#  'ciúmes.pkl',
#  'tomando.pkl',
#  'whoever.pkl',
#  '-rt.pkl',
#  'ignore.pkl',
#  'tampoco.pkl',
#  'on.pkl',
#  'hago.pkl',
#  'sup.pkl',
#  'trauma.pkl',
#  'يديك.pkl',
#  'desaparecer.pkl',
#  'fofa.pkl',
#  'سماء.pkl',
#  'panza.pkl',
#  'フ.pkl',
#  'お願い.pkl',
#  'grow.pkl',
#  'segment.pkl',
#  'ένα.pkl',
#  'soal.pkl',
#  'าเป.pkl',
#  'なんて.pkl',
#  'الأصدقاء.pkl',
#  'application.pkl',
#  'lightly.pkl',
#  'survivor.pkl',
#  'apertura.pkl',
#  'ward.pkl',
#  'وسائل.pkl',
#  'creepy.pkl',
#  'chinese.pkl',
#  'travels.pkl',
#  'waving.pkl',
#  'shots.pkl',
#  'design.pkl',
#  'brighten.pkl',
#  'ごめん.pkl',
#  'بع.pkl',
#  'الموضوع.pkl',
#  'karte.pkl',
#  '5h.pkl',
#  '6s.pkl',
#  'hiç.pkl',
#  'ade.pkl',
#  'себе.pkl',
#  'además.pkl',
#  'toujours.pkl',
#  'ms.pkl',
#  'classics.pkl',
#  'nunggu.pkl',
#  'الفتن.pkl',
#  'md.pkl',
#  'misses.pkl',
#  'tool.pkl',
#  'اء.pkl',
#  'الصغير.pkl',
#  'texted.pkl',
#  'فرح.pkl',
#  'าน.pkl',
#  'utama.pkl',
#  'hue.pkl',
#  'هدوء.pkl',
#  'هههههههه.pkl',
#  '몸.pkl',
#  'adolescente.pkl',
#  '-y.pkl',
#  'fzr.pkl',
#  'wireless.pkl',
#  'todos.pkl',
#  'onlar.pkl',
#  'sliding.pkl',
#  'chicos.pkl',
#  'unicorn.pkl',
#  'imagined.pkl',
#  'nearest.pkl',
#  'ruins.pkl',
#  'diferente.pkl',
#  'applied.pkl',
#  'funded.pkl',
#  'つω.pkl',
#  'ﾉд.pkl',
#  '무서워.pkl',
#  '차라리.pkl',
#  'queira.pkl',
#  'uu.pkl',
#  'goodbye.pkl',
#  'tq.pkl',
#  'parler.pkl',
#  'isang.pkl',
#  'นใส.pkl',
#  'homem.pkl',
#  'والمسلمات.pkl',
#  'tío.pkl',
#  'brothers.pkl',
#  'underground.pkl',
#  'حبيبتي.pkl',
#  'dire.pkl',
#  'direction.pkl',
#  'oficialmente.pkl',
#  '저희.pkl',
#  'ise.pkl',
#  'lover.pkl',
#  'nonton.pkl',
#  'newly.pkl',
#  'ゞ.pkl',
#  'casa.pkl',
#  'delivering.pkl',
#  'الأحد.pkl',
#  'kemana.pkl',
#  'glitch.pkl',
#  'accomplish.pkl',
#  'мое.pkl',
#  'بقيت.pkl',
#  'องล.pkl',
#  'lgbt.pkl',
#  'takin.pkl',
#  'feed.pkl',
#  'حقك.pkl',
#  '201.pkl',
#  'lloyd.pkl',
#  'check.pkl',
#  'lad.pkl',
#  '반.pkl',
#  'gün.pkl',
#  'ему.pkl',
#  'senpai.pkl',
#  'ü.pkl',
#  '어째서.pkl',
#  'عدد.pkl',
#  'planes.pkl',
#  'julio.pkl',
#  'equals.pkl',
#  'öyle.pkl',
#  'editing.pkl',
#  'kayong.pkl',
#  'だった.pkl',
#  'おつありです.pkl',
#  'rogue.pkl',
#  '#エロ動画.pkl',
#  'gesto.pkl',
#  'toute.pkl',
#  'اشف.pkl',
#  'nom.pkl',
#  'chupa.pkl',
#  'aquel.pkl',
#  'focus.pkl',
#  'بھی.pkl',
#  'deberíamos.pkl',
#  '고맙습니다.pkl',
#  'nave.pkl',
#  'อนต.pkl',
#  'benar.pkl',
#  'العافيه.pkl',
#  'coming.pkl',
#  'hermano.pkl',
#  'amendment.pkl',
#  'dada.pkl',
#  'جبل.pkl',
#  'awal.pkl',
#  'arkadaşlar.pkl',
#  'اغلب.pkl',
#  'barco.pkl',
#  'china.pkl',
#  'sing.pkl',
#  'ж.pkl',
#  'chili.pkl',
#  'あのね.pkl',
#  'llamada.pkl',
#  'ourselves.pkl',
#  'bite.pkl',
#  'أمس.pkl',
#  'woy.pkl',
#  'день.pkl',
#  'कल.pkl',
#  '심장이.pkl',
#  'не.pkl',
#  'email.pkl',
#  'usah.pkl',
#  'begins.pkl',
#  'گا.pkl',
#  'connection.pkl',
#  'quiso.pkl',
#  'tangina.pkl',
#  'passengers.pkl',
#  '이거.pkl',
#  'neighborhood.pkl',
#  'ｯ.pkl',
#  'ايوه.pkl',
#  'misericórdia.pkl',
#  'purchasing.pkl',
#  'matrimonio.pkl',
#  'além.pkl',
#  'joke.pkl',
#  'cambridge.pkl',
#  'proves.pkl',
#  'chal.pkl',
#  'puma.pkl',
#  '#socialmedia.pkl',
#  'primeras.pkl',
#  "today's.pkl",
#  'عالية.pkl',
#  'tradition.pkl',
#  'engraçada.pkl',
#  'montreal.pkl',
#  'masterpiece.pkl',
#  'familia.pkl',
#  'whoop.pkl',
#  'insanın.pkl',
#  'นะ.pkl',
#  'ในช.pkl',
#  'mames.pkl',
#  'tod@s.pkl',
#  '고개를.pkl',
#  '머리를.pkl',
#  'melting.pkl',
#  'nya.pkl',
#  'reduce.pkl',
#  'warfare.pkl',
#  'gpp.pkl',
#  'dance.pkl',
#  'hubo.pkl',
#  '200.pkl',
#  'months.pkl',
#  'shoutout.pkl',
#  'collective.pkl',
#  'ghana.pkl',
#  'önüne.pkl',
#  'miércoles.pkl',
#  'segura.pkl',
#  'dumbest.pkl',
#  'prospects.pkl',
#  'lastima.pkl',
#  'california.pkl',
#  'wifi.pkl',
#  '@rt_com.pkl',
#  'حلوة.pkl',
#  'dreams.pkl',
#  'rough.pkl',
#  'departure.pkl',
#  'عام.pkl',
#  'perfección.pkl',
#  'تبارك.pkl',
#  '#libra.pkl',
#  'che.pkl',
#  'apa.pkl',
#  'gucci.pkl',
#  'おつかれさま.pkl',
#  'しかし.pkl',
#  'jefferson.pkl',
#  'غي.pkl',
#  'ง.pkl',
#  'today.pkl',
#  'asıl.pkl',
#  'أبا.pkl',
#  'enable.pkl',
#  'deposit.pkl',
#  'domain.pkl',
#  'wk.pkl',
#  'menina.pkl',
#  'ل.pkl',
#  '๑.pkl',
#  '한번.pkl',
#  'karar.pkl',
#  '귀여워.pkl',
#  'yooooo.pkl',
#  'colored.pkl',
#  'وقتها.pkl',
#  'soooooo.pkl',
#  'kann.pkl',
#  'cuisine.pkl',
#  'มากกว.pkl',
#  'popcorn.pkl',
#  'beş.pkl',
#  'wealth.pkl',
#  'carrying.pkl',
#  'crush.pkl',
#  'kidnapped.pkl',
#  'tdk.pkl',
#  'replies.pkl',
#  'material.pkl',
#  '아빠.pkl',
#  'towards.pkl',
#  'التعامل.pkl',
#  'pendant.pkl',
#  'وجد.pkl',
#  'info.pkl',
#  'vender.pkl',
#  '#tbs.pkl',
#  'fechar.pkl',
#  'bienvenido.pkl',
#  'reed.pkl',
#  'cursos.pkl',
#  '@soompi.pkl',
#  'carente.pkl',
#  'شاب.pkl',
#  'فصل.pkl',
#  '@yahoonewstopics.pkl',
#  '➋.pkl',
#  'วคร.pkl',
#  'ね.pkl',
#  'a&amp.pkl',
#  'nite.pkl',
#  'mr.pkl',
#  'قرأ.pkl',
#  'самом.pkl',
#  'mijn.pkl',
#  'harrison.pkl',
#  'dirty.pkl',
#  'นอะไรท.pkl',
#  'brian.pkl',
#  'llevó.pkl',
#  'mrs.pkl',
#  'alexa.pkl',
#  '*.pkl',
#  'lords.pkl',
#  'optimistic.pkl',
#  'ohh.pkl',
#  'tuiter.pkl',
#  'verdadeiro.pkl',
#  '77.pkl',
#  'sano.pkl',
#  'arizona.pkl',
#  'obrigada.pkl',
#  '送料.pkl',
#  'fan.pkl',
#  'bienvenidos.pkl',
#  'gasolina.pkl',
#  'diem.pkl',
#  'maintenance.pkl',
#  'بد.pkl',
#  'القوة.pkl',
#  'بارك.pkl',
#  'ˊᗜˋ*.pkl',
#  'الح.pkl',
#  '一応.pkl',
#  'honduras.pkl',
#  'estranho.pkl',
#  'o.pkl',
#  'chama.pkl',
#  'ظهور.pkl',
#  '@twitter.pkl',
#  'ขอให.pkl',
#  'lions.pkl',
#  'searching.pkl',
#  'brownies.pkl',
#  'apartment.pkl',
#  '花.pkl',
#  'suspected.pkl',
#  'confío.pkl',
#  'carbon.pkl',
#  'typing.pkl',
#  'hoy.pkl',
#  'تبدأ.pkl',
#  'うわぁ.pkl',
#  'ma.pkl',
#  'acordando.pkl',
#  'naomi.pkl',
#  'stance.pkl',
#  'حياة.pkl',
#  'город.pkl',
#  'الصور.pkl',
#  'give.pkl',
#  'mengapa.pkl',
#  'smth.pkl',
#  'بره.pkl',
#  '이걸.pkl',
#  'じ.pkl',
#  'versus.pkl',
#  '漫画.pkl',
#  'fitbit.pkl',
#  '98.pkl',
#  'sons.pkl',
#  '#バイト.pkl',
#  'قولوا.pkl',
#  'всю.pkl',
#  'irrita.pkl',
#  'มห.pkl',
#  'mulheres.pkl',
#  '乃木坂46.pkl',
#  'thumbs.pkl',
#  'mij.pkl',
#  'toys.pkl',
#  'zip.pkl',
#  'начала.pkl',
#  'tek.pkl',
#  'あんさんぶるスターズ.pkl',
#  'صف.pkl',
#  'representa.pkl',
#  'leben.pkl',
#  'سليم.pkl',
#  'vehicles.pkl',
#  '凄い.pkl',
#  'ug.pkl',
#  'bambam.pkl',
#  '아무.pkl',
#  '제가.pkl',
#  'jap.pkl',
#  '#6.pkl',
#  'follow.pkl',
#  'tc.pkl',
#  'ape.pkl',
#  'นเร.pkl',
#  'dedim.pkl',
#  'fort.pkl',
#  'sweatshirt.pkl',
#  '않을.pkl',
#  'ด.pkl',
#  'alaska.pkl',
#  'wo.pkl',
#  '身長.pkl',
#  '암튼.pkl',
#  'minha.pkl',
#  'مبروك.pkl',
#  'wide.pkl',
#  'entiendes.pkl',
#  'portable.pkl',
#  'aboard.pkl',
#  'дома.pkl',
#  'inicio.pkl',
#  'นใหม.pkl',
#  'صرف.pkl',
#  'لقيت.pkl',
#  'liar.pkl',
#  'harga.pkl',
#  'bangs.pkl',
#  'رجعت.pkl',
#  'โอเค.pkl',
#  'اثر.pkl',
#  'major.pkl',
#  'nicolas.pkl',
#  'ban.pkl',
#  'مب.pkl',
#  'år.pkl',
#  'letak.pkl',
#  '#mexico.pkl',
#  '늘.pkl',
#  'volvió.pkl',
#  'فـ.pkl',
#  'ignorancia.pkl',
#  'coro.pkl',
#  'rapist.pkl',
#  'tante.pkl',
#  'يا.pkl',
#  'っと.pkl',
#  'viajar.pkl',
#  'lion.pkl',
#  "quelqu'un.pkl",
#  'activist.pkl',
#  '또는.pkl',
#  'alarma.pkl',
#  'onto.pkl',
#  'unbelievable.pkl',
#  'её.pkl',
#  'albert.pkl',
#  'ายๆ.pkl',
#  'وهو.pkl',
#  '뒤에.pkl',
#  'speaking.pkl',
#  'diciembre.pkl',
#  'معاه.pkl',
#  'kapalı.pkl',
#  'شاهد.pkl',
#  'フォロー失礼します.pkl',
#  'baş.pkl',
#  'mover.pkl',
#  '많고.pkl',
#  '頑張る.pkl',
#  'تصبح.pkl',
#  'after.pkl',
#  'gustos.pkl',
#  'お願いします.pkl',
#  '있어야.pkl',
#  'unfollowed.pkl',
#  'already.pkl',
#  'всем.pkl',
#  'ممتاز.pkl',
#  '당신이.pkl',
#  'novo.pkl',
#  'incluso.pkl',
#  'presentación.pkl',
#  'caga.pkl',
#  'العبد.pkl',
#  'آمن.pkl',
#  'locks.pkl',
#  'twist.pkl',
#  'jupiter.pkl',
#  'idi.pkl',
#  'ülke.pkl',
#  '어때.pkl',
#  'он.pkl',
#  '黒.pkl',
#  'yay.pkl',
#  'ไทย.pkl',
#  'cyber.pkl',
#  'beba.pkl',
#  'ronda.pkl',
#  'sacó.pkl',
#  'investigación.pkl',
#  'نفر.pkl',
#  'buzzfeed.pkl',
#  'republican.pkl',
#  'fotoğraf.pkl',
#  'aracılığıyla.pkl',
#  'joder.pkl',
#  'اقسم.pkl',
#  'jako.pkl',
#  'get.pkl',
#  'feast.pkl',
#  'choking.pkl',
#  'dislike.pkl',
#  'discount.pkl',
#  'aesthetic.pkl',
#  'người.pkl',
#  'этой.pkl',
#  'دور.pkl',
#  "c'è.pkl",
#  '좋아.pkl',
#  'seus.pkl',
#  'دوست.pkl',
#  "other's.pkl",
#  'breaks.pkl',
#  'المجلس.pkl',
#  'vê.pkl',
#  'anterior.pkl',
#  'ballet.pkl',
#  '#sunset.pkl',
#  'maju.pkl',
#  'خادم.pkl',
#  'outside.pkl',
#  'doktor.pkl',
#  '발.pkl',
#  'ᕗ.pkl',
#  'britney.pkl',
#  'unemployed.pkl',
#  'género.pkl',
#  '여러.pkl',
#  'order.pkl',
#  'touch.pkl',
#  '했다.pkl',
#  '선물.pkl',
#  'helpful.pkl',
#  'pst.pkl',
#  'hogwarts.pkl',
#  'soyez.pkl',
#  'disneyland.pkl',
#  'law.pkl',
#  'البنت.pkl',
#  'hyun.pkl',
#  'ᵕ.pkl',
#  '밥.pkl',
#  'silêncio.pkl',
#  '술.pkl',
#  'bells.pkl',
#  'سعودي.pkl',
#  'protagonista.pkl',
#  'apalagi.pkl',
#  'purposes.pkl',
#  'وعدم.pkl',
#  'italiano.pkl',
#  'bici.pkl',
#  'आग.pkl',
#  '#amateur.pkl',
#  'themes.pkl',
#  'tlga.pkl',
#  'ـم.pkl',
#  'sonic.pkl',
#  'states.pkl',
#  'tarih.pkl',
#  'sounded.pkl',
#  '평생.pkl',
#  'dolphin.pkl',
#  'نكون.pkl',
#  'вопрос.pkl',
#  'cara.pkl',
#  'กเก.pkl',
#  'cosmic.pkl',
#  'kurus.pkl',
#  'wäre.pkl',
#  'começando.pkl',
#  'bills.pkl',
#  '최고의.pkl',
#  'ash.pkl',
#  '#rtした人全員フォローする.pkl',
#  'tenerte.pkl',
#  '男性.pkl',
#  'قائد.pkl',
#  'curiosity.pkl',
#  'soo.pkl',
#  'そうそう.pkl',
#  'kendimi.pkl',
#  'illinois.pkl',
#  'あっ.pkl',
#  'escribiendo.pkl',
#  'मत.pkl',
#  'town.pkl',
#  'boyfriend.pkl',
#  'الخاطر.pkl',
#  'について.pkl',
#  'tagging.pkl',
#  'ข.pkl',
#  'enemigos.pkl',
#  'impression.pkl',
#  'estará.pkl',
#  'deserve.pkl',
#  'تعد.pkl',
#  'limpia.pkl',
#  '수도.pkl',
#  'ebook.pkl',
#  'tej.pkl',
#  'banned.pkl',
#  'preocupación.pkl',
#  'servir.pkl',
#  'blacks.pkl',
#  'يكون.pkl',
#  'شرط.pkl',
#  'nyaman.pkl',
#  '#エロ.pkl',
#  'الان.pkl',
#  'mexican.pkl',
#  '#الرياض.pkl',
#  'condiciones.pkl',
#  'manusia.pkl',
#  'ferry.pkl',
#  'sorpresas.pkl',
#  '28th.pkl',
#  'อยากด.pkl',
#  'preparar.pkl',
#  'انظر.pkl',
#  '画像.pkl',
#  'مثلا.pkl',
#  '#bitcoin.pkl',
#  'าช.pkl',
#  '99.pkl',
#  'autre.pkl',
#  'had.pkl',
#  'japón.pkl',
#  'palos.pkl',
#  'المهم.pkl',
#  'mw.pkl',
#  'reached.pkl',
#  'told.pkl',
#  'ادخل.pkl',
#  'ruby.pkl',
#  'handled.pkl',
#  'فعلت.pkl',
#  'apaixonado.pkl',
#  'olivia.pkl',
#  'chorei.pkl',
#  'vielen.pkl',
#  'reaches.pkl',
#  'cry.pkl',
#  'ﾟﾟ.pkl',
#  'நட.pkl',
#  'tránsito.pkl',
#  'estás.pkl',
#  'sugar.pkl',
#  'christine.pkl',
#  'よろしく.pkl',
#  'kate.pkl',
#  'ethnic.pkl',
#  'ada.pkl',
#  '해야.pkl',
#  'باذن.pkl',
#  '잘못.pkl',
#  'them.pkl',
#  'counting.pkl',
#  'pedimos.pkl',
#  'ac.pkl',
#  'exile.pkl',
#  'joão.pkl',
#  'parties.pkl',
#  'عبارة.pkl',
#  'weird.pkl',
#  'l.pkl',
#  'سخر.pkl',
#  'safari.pkl',
#  'aunque.pkl',
#  'nena.pkl',
#  '初音ミク.pkl',
#  'theo.pkl',
#  'complicado.pkl',
#  'trendy.pkl',
#  '横浜.pkl',
#  'paket.pkl',
#  '애들.pkl',
#  'recursos.pkl',
#  'galit.pkl',
#  'memilih.pkl',
#  'まじか.pkl',
#  'gives.pkl',
#  'tra.pkl',
#  'number.pkl',
#  'newsletter.pkl',
#  '영상.pkl',
#  'hometown.pkl',
#  'halfway.pkl',
#  'sempurna.pkl',
#  'conozco.pkl',
#  'berikan.pkl',
#  'conheço.pkl',
#  'discounts.pkl',
#  'argumento.pkl',
#  'برنامج.pkl',
#  'طي.pkl',
#  'anjir.pkl',
#  '됩니다.pkl',
#  'gibt.pkl',
#  '사실은.pkl',
#  'الذكر.pkl',
#  'posição.pkl',
#  'washington.pkl',
#  'ออออ.pkl',
#  '반응.pkl',
#  'solidaridad.pkl',
#  'kame.pkl',
#  'inilah.pkl',
#  '죽은.pkl',
#  'writer.pkl',
#  'japon.pkl',
#  'paki.pkl',
#  'duties.pkl',
#  'look.pkl',
#  'آخر.pkl',
#  'العامة.pkl',
#  'fueran.pkl',
#  'duas.pkl',
#  'سلمان.pkl',
#  'polite.pkl',
#  '올해.pkl',
#  'durante.pkl',
#  'olmuyor.pkl',
#  'bread.pkl',
#  'estadio.pkl',
#  'codes.pkl',
#  'وحسن.pkl',
#  'freestyle.pkl',
#  '자세한.pkl',
#  'mantap.pkl',
#  'quelle.pkl',
#  ...]

# %%
compare = ['rapist']

# %%
traces = []

# %%
df['Date'][300].year
# Out:
# 2016

# %%
for word in compare:
    df = pd.read_csv(str("daily_onegrams/daily_ranks/"+word+".txt"), sep=" ", skipinitialspace=True)
    df['Date'] = [datetime.strptime(date, '%Y-%m-%d') for date in df['Date']]
    df['Year'] = [df['Date'].iloc(date).year for date in df['Date']]
    #df['Day'] = [df['Date'][date].tm_yday for date in df['Date']]
    r = lambda: random.randint(0,255)
    color = str('#%02X%02X%02X' % (r(),r(),r()))
    trace = go.Scatter(x=df['Date'], y=df['Rank'], name=str(word),line = dict(color = color))
    traces.append(trace)
data = traces

layout = dict(
    title = str("Comparing "+compare[0]+" to "+compare[1]),
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = str(word+'_time-series-simple.html'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-cfc045c3c9c7> in <module>()
#       2     df = pd.read_csv(str("daily_onegrams/daily_ranks/"+word+".txt"), sep=" ", skipinitialspace=True)
#       3     df['Date'] = [datetime.strptime(date, '%Y-%m-%d') for date in df['Date']]
# ----> 4     df['Year'] = [df['Date'].iloc(date).year for date in df['Date']]
#       5     #df['Day'] = [df['Date'][date].tm_yday for date in df['Date']]
#       6     r = lambda: random.randint(0,255)
#
# <ipython-input-22-cfc045c3c9c7> in <listcomp>(.0)
#       2     df = pd.read_csv(str("daily_onegrams/daily_ranks/"+word+".txt"), sep=" ", skipinitialspace=True)
#       3     df['Date'] = [datetime.strptime(date, '%Y-%m-%d') for date in df['Date']]
# ----> 4     df['Year'] = [df['Date'].iloc(date).year for date in df['Date']]
#       5     #df['Day'] = [df['Date'][date].tm_yday for date in df['Date']]
#       6     r = lambda: random.randint(0,255)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __call__(self, axis)
#      96
#      97         if axis is not None:
# ---> 98             axis = self.obj._get_axis_number(axis)
#      99         new_self.axis = axis
#     100         return new_self
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_axis_number(self, axis)
#     373                 pass
#     374         raise ValueError('No axis named {0} for object type {1}'
# --> 375                          .format(axis, type(self)))
#     376
#     377     def _get_axis_name(self, axis):
#
# ValueError: No axis named 2016-01-02 00:00:00 for object type <class 'pandas.core.series.Series'>
